# %%
import numpy as np

a = np.array([1,2,4,5]) 
b = np.array([23, 4, 6, 7])

print(np.shape(a))
print(np.shape(b))
# Out:
# (4,)
# (4,)

# %%
print(a+b)
print(a-b)
print(a*b)
# Out:
# [24  6 10 12]
# [-22  -2  -2  -2]
# [23  8 24 35]

# %%
c = np.arange(18).reshape(2, 3, 3)
np.sum(c, axis=2)
# Out:
# array([[ 3, 12, 21],
#        [30, 39, 48]])

# %%
d = np.arange(16).reshape(4, 4)
z1, z2 = np.split(d, 2, axis=1)
z1
# Out:
# array([[ 0,  1],
#        [ 4,  5],
#        [ 8,  9],
#        [12, 13]])
